# %%
''' 1) Encontre os valores únicos das colunas "Nível 1 - Setor" e "Estado" para identificar as atividades econômicas presentes na base de dados e se todos os Estados do Brasil estão presentes no DataFrame.

2) Filtre o DataFrame somente com os dados dos Estados da região Sul do Brasil.

3) Filtre o DataFrame somente com os dados de "Mudança de Uso da Terra e Floresta" que sejam do Estado do Amazonas.

4) Encontre o valor máximo de emissão do ano de 2021 para os dados de "Agropecuária" no Estado do Pará.'''

# 1 

import pandas as pd 
dados_emissoes = pd.read_excel('dados_emissoes.xlsx') 
dados_emissoes['Nível 1 - Setor'].unique()
dados_emissoes['Estado'].unique()
# Out:
# array(['SP', 'BA', 'RJ', 'MG', 'SE', 'PR', nan, 'RO', 'AM', 'PA', 'TO',
#        'MA', 'PI', 'CE', 'RN', 'PB', 'PE', 'AL', 'MT', 'MS', 'GO', 'DF',
#        'ES', 'SC', 'RS', 'AC', 'AP', 'RR', 'BR'], dtype=object)

# %%
# 2

dados_emissoes[dados_emissoes['Estado'].isin(['PR', 'SC', 'RS'])]
# Out:
#                            Nível 1 - Setor  ... Unnamed: 63
# 35                   Processos Industriais  ...         NaN
# 36                   Processos Industriais  ...         NaN
# 37                   Processos Industriais  ...         NaN
# 110                  Processos Industriais  ...         NaN
# 111                  Processos Industriais  ...         NaN
# ...                                    ...  ...         ...
# 103221  Mudança de Uso da Terra e Floresta  ...         NaN
# 103222  Mudança de Uso da Terra e Floresta  ...         NaN
# 103223  Mudança de Uso da Terra e Floresta  ...         NaN
# 103224  Mudança de Uso da Terra e Floresta  ...         NaN
# 103225  Mudança de Uso da Terra e Floresta  ...         NaN
#
# [12212 rows x 64 columns]

# %%
# 3

dados_emissoes[(dados_emissoes['Nível 1 - Setor'] == 'Mudança de Uso da Terra e Floresta') & (dados_emissoes['Estado'] == 'AM')]
# Out:
#                            Nível 1 - Setor  ... Unnamed: 63
# 81262   Mudança de Uso da Terra e Floresta  ...         NaN
# 81271   Mudança de Uso da Terra e Floresta  ...         NaN
# 81280   Mudança de Uso da Terra e Floresta  ...         NaN
# 81289   Mudança de Uso da Terra e Floresta  ...         NaN
# 81298   Mudança de Uso da Terra e Floresta  ...         NaN
# ...                                    ...  ...         ...
# 102803  Mudança de Uso da Terra e Floresta  ...         NaN
# 102812  Mudança de Uso da Terra e Floresta  ...         NaN
# 102821  Mudança de Uso da Terra e Floresta  ...         NaN
# 102830  Mudança de Uso da Terra e Floresta  ...         NaN
# 102839  Mudança de Uso da Terra e Floresta  ...         NaN
#
# [354 rows x 64 columns]

# %%
# 4

dados_emissoes.loc[(dados_emissoes['Nível 1 - Setor'] == 'Agropecuária') & (dados_emissoes['Estado'] == 'PA'), 2021].max()
# Out:
# 36856969.7986
